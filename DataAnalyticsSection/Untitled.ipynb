# %%
ls
# Out:
# Day1.py              Day2.md              Untitled.ipynb
# Day1HW.py            Netflix_Dataset.csv  WorkingWithCSV.py

# %%
import numpy as np
import pandas as pd
import sys
py_array = [1, 2, 3, 4, 5, 6, 7]
py_array_size = sys.getsizeof(1) * len(py_array)
numpy_array = np.array([1, 2, 3, 4, 5, 6, 7])
numpy_array_size = numpy_array.itemsize * numpy_array.size
sys.stdout.write(str(numpy_array_size))
print('\n')
sys.stdout.write(str(py_array_size))
# Out:
# 56
#
# 196/Users/brandonbunch/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_csv('./Netflix_Dataset.csv') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9266 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   Director               7120 non-null   object
#  9   Writer                 7615 non-null   object
#  10  Actors                 9314 non-null   object
#  11  View Rating            6827 non-null   object
#  12  IMDb Score             9417 non-null   float64
#  13  Rotten Tomatoes Score  5445 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Hidden Gem Score   IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# count       9415.000000  9417.000000            5445.000000       4082.000000
# mean           5.540733     6.955517              64.691276         58.113425
# std            2.447462     0.899681              25.269466         17.143187
# min            0.600000     1.600000               0.000000          6.000000
# 25%            3.400000     6.500000              49.000000         46.000000
# 50%            5.300000     7.000000              70.000000         59.000000
# 75%            8.100000     7.500000              85.000000         71.000000
# max            9.800000     9.700000             100.000000        100.000000
#
#        Awards Received  Awards Nominated For    IMDb Votes
# count      5226.000000           6376.000000  9.415000e+03
# mean          9.735936             16.035602  6.014725e+04
# std          19.524116             32.209094  1.463837e+05
# ...

# %%
df.describe(include='all')
# Out:
#           Title  Genre    Tags Languages Series or Movie  Hidden Gem Score  \
# count      9425   9400    9389      9266            9425       9415.000000
# unique     9166   1531    8552      1209               2               NaN
# top     Kingdom  Drama  Dramas   English           Movie               NaN
# freq          4    647      35      3754            7010               NaN
# mean        NaN    NaN     NaN       NaN             NaN          5.540733
# std         NaN    NaN     NaN       NaN             NaN          2.447462
# min         NaN    NaN     NaN       NaN             NaN          0.600000
# 25%         NaN    NaN     NaN       NaN             NaN          3.400000
# 50%         NaN    NaN     NaN       NaN             NaN          5.300000
# 75%         NaN    NaN     NaN       NaN             NaN          8.100000
# max         NaN    NaN     NaN       NaN             NaN          9.800000
#
# ...

# %%
spielbergs = df[df.Director == 'Steven Spielberg']
good_spielbergs = spielbergs[spielbergs['Hidden Gem Score'] > 3.4]

# %%
spielbergs
# Out:
# based...
# 8841  Sci-Fi & Fantasy,Action Sci-Fi & Fantasy,Actio...
# 9027  Family Adventures,Children & Family Films,Film...
#
#                                               Languages Series or Movie  \
# 417                                     English, French           Movie
# 1163                                            English          Series
# 2732                                            English           Movie
# 3254                                            English           Movie
# 4009  English, Bulgarian, Spanish, Russian, Mandarin...          Series
# 4515                                            English           Movie
# 5511                                     English, Hindi           Movie
# 6213                                            English           Movie
# 6239                           English, German, Russian           Movie
# 6767                                            English           Movie
# ...

# %%
good_USA_Spielbergs = good_spielbergs[good_spielbergs['Country Availability'] == 'United States']
good_USA_Spielbergs
# Out:
#           Title                                   Genre  \
# 8673  War Horse  Action, Adventure, Drama, History, War
#
#                                                    Tags        Languages  \
# 8673  Dramas,Dramas based on a book,Historical Drama...  English, German
#
#      Series or Movie  Hidden Gem Score Country Availability  Runtime  \
# 8673           Movie               3.6        United States  > 2 hrs
#
#               Director                                             Writer  \
# 8673  Steven Spielberg  Nick Stafford, Michael Morpurgo, Richard Curti...
#
#       ... Netflix Release Date                        Production House  \
# 8673  ...           2015-04-14  Amblin Entertainment, Kennedy/Marshall
#
#                                 Netflix Link  \
# 8673  https://www.netflix.com/watch/70172928
#
#                                  IMDb Link  \
# 8673  https://www.imdb.com/title/tt1568911
#
#                                                 Summary  IMDb Votes  \
# ...

# %%
de_dup_df = df.drop_duplicates(subset=['Title'])

# %%
de_dup_df.describe(include='all')
# df[df['A'].str.contains("hello")]
noNa = de_dup_df[de_dup_df['Country Availability'].notna()]
american_movies = noNa[noNa['Country Availability'].str.contains('United States')].reset_index()
italy_movies = noNa[noNa['Country Availability'].str.contains('Italy')].reset_index()
spain_movies = noNa[noNa['Country Availability'].str.contains('Spain')].reset_index()
uk_movies = noNa[noNa['Country Availability'].str.contains('United Kingdom')].reset_index()
# Out:
# 7.114514514514515
# 7.143343343343344
# 7.146646646646647
# 7.08008008008008
# 61.11292200232829
# 59.47291092745638
# 60.14476386036961
# 59.19518486672399

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(['America'], american_movies['Metacritic Score'].mean())
ax.bar(['Italy'], italy_movies['Metacritic Score'].mean())
ax.bar(['Spain'], spain_movies['Metacritic Score'].mean())
ax.bar(['United Kingdom'], uk_movies['Metacritic Score'].mean())

plt.show()

# %%
# directors_top_movies = de_dup_df.to_frame()
# directors_top_movies = directors_top_movies.iloc[: , :-1]
# directors_top_movies

# de_dup_df.drop_duplicates(subset=['Director'], keep='first')

# %%
directors_top_movies = directors_top_movies.reset_index()

# %%
directors_top_movies = directors_top_movies.drop_duplicates('Director').reset_index(drop=True)

# %%
directors_top_movies = directors_top_movies.sort_values('Director').reset_index(drop=True)
directors_top_movies
# Out:
#       index                    Director  Hidden Gem Score             Title
# 0         0             A.R. Murugadoss               2.1            Spyder
# 1         1                Aamir Bashir               7.9             Harud
# 2         2     Aamir Khan, Amole Gupte               4.4  Taare Zameen Par
# 3         3               Aanand L. Rai               3.4    Tanu Weds Manu
# 4         4  Aaron Hann, Mario Miscione               2.8            Circle
# ...     ...                         ...               ...               ...
# 4209   4209                 Åsa Sandzén               8.4        Still Born
# 4210   4210   Çagan Irmak, Veysel Aslan               3.2             Alone
# 4211   4211                 Éric Rohmer               5.7      Summers Over
# 4212   4212            Ömer Faruk Sorak               3.7        Yahsi Bati
# 4213   4213                 Özcan Deniz               6.2    Water and Fire
#
# [4214 rows x 4 columns]

# %%
properties = pd.read_csv('../yucky.csv')
properties = properties.reset_index()

# %%
replace_index = properties.loc[properties['level_0'].str.contains(" |may")].index

# %%
properties.loc[replace_index, 'level_0'] = np.nan

# %%
properties
# Out:
#    level_0 level_1 level_2 I'm a jerk
# 0      NaN    june    july     august
# 1        0       0       0          0
# 2        1       1      14         13
# 3        2       2      22         32
# 4        3       3       5         67
# 5      NaN     NaN     NaN        NaN
# 6        4       4      65         34
# 7        5       5      61         12
# 8        6       6      45         32
# 9        7       7      90         11
# 10     NaN     NaN     NaN        NaN
# 11       8       8      34         23
# 12       9       9      23         33
# 13     NaN     NaN     NaN        NaN
# 14      10      10      11         11

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.arange(10)
plt.plot(data)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.rand(2000).cumsum())

ticks = ax.set_xticks([0, 500, 1000, 1500, 2000])
labels = ax.set_xticklabels(['zero', '5-hundo', 'a grand', '1.5 grand', '2 grand'])
ax.set_title('We made a plot with some ticks, labels, and title!')
#Text(0.5, 1.0, 'We made a plot with some ticks, labels, and title!')
ax.set_xlabel('PROFIT')
#Text(0.5, 0, 'PROFIT')
plt.show()
